# %%
import subprocess

subprocess.run(['python', 'DataHandler.py','--dataset','YAGO'])
# Out:
# 2024-07-28 19:54:29: Start preprocess YAGO

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed
import os
# os.chdir(os.path.abspath("")+"/03_RobustTKG/MyWork/src_DGAD/ipynbFiles/")
# print(os.path.abspath(""))
# print(os.getcwd())

# 定义参数组合
param_combinations = [
   {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "1",
       "conf-threshold":"0.9",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "2",
        "conf-threshold":"0.9",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "3",
        "conf-threshold":"0.9",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "4",
        "conf-threshold":"0.9",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "5",
        "conf-threshold":"0.9",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "6",
        "conf-threshold":"0.9",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "7",
        "conf-threshold":"0.9",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "8",
        "conf-threshold":"0.9",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_sensi_hislen_WIKI.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# # 使用 ProcessPoolExecutor 并行执行命令
# with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
#     commands = [create_command(params) for params in param_combinations]
#     futures = [executor.submit(run_command, cmd) for cmd in commands]
#     for future in as_completed(futures):
#         returncode = future.result()
#         print(f"Process finished with return code {returncode}")



# 依次执行每个参数组合
for params in param_combinations:
    command = create_command(params)
    print(f"Running command: {' '.join(command)}")
    returncode = run_command(command)
    if returncode == 0:
        print(f"Finished command successfully: {' '.join(command)}")
    else:
        print(f"Command failed with return code {returncode}: {' '.join(command)}")
# Out:
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 1 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 1 --conf-threshold 0.9
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 2 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 2 --conf-threshold 0.9
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 3 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 3 --conf-threshold 0.9
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 4 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 4 --conf-threshold 0.9
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 5 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 5 --conf-threshold 0.9
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 6 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 6 --conf-threshold 0.9
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 7 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 7 --conf-threshold 0.9
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 8 --conf-threshold 0.9
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 0 --dataset WIKI --lambda1 1.0 --lambda3 1.0 --history-len 8 --conf-threshold 0.9
