# %% [markdown]
# # 噪声数据，训练temp+bypass

# %%
from concurrent.futures import ProcessPoolExecutor, as_completed
import subprocess
# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.8",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14s",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.5",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14s",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.5",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut20",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut50",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../main.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # REGCN的性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN",
        "filter":"1",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "history-len": "2",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN",
        "filter":"1",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN",
        "filter":"1",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_rawdata_REGCN.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 分别测试temp, bypass, context

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut20",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut20",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut50",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut50",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14s",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "1.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14s",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../main.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")
        
# # 使用 ProcessPoolExecutor 并行执行命令
# with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
#     commands = [create_command(params) for params in param_combinations[6:]]
#     futures = [executor.submit(run_command, cmd) for cmd in commands]
#     for future in as_completed(futures):
#         returncode = future.result()
#         print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 原始数据集上，置信度是否让模型更加稳定

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut20",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14s",
        "history-len": "3",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # QGTC-Net性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.4",
    #     "model":"REGCN",
    #     "noise-strategy":"1",
    #     "filter":"1",
    #     # "attack":"raw",
    #     "gpu": "0",
    #     "dataset": "ICEWS18",
    #     "history-len": "4",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "conf-threshold":"0.8",
    #     "use-conf":"1",
    #     "use-query":"1",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.4",
    #     "model":"REGCN",
    #     "noise-strategy":"1",
    #     "filter":"1",
    #     # "attack":"raw",
    #     "gpu": "2",
    #     "dataset": "ICEWS18",
    #     "history-len": "5",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "conf-threshold":"0.8",
    #     "use-conf":"1",
    #     "use-query":"1",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.4",
    #     "model":"REGCN",
    #     "noise-strategy":"1",
    #     "filter":"1",
    #     # "attack":"raw",
    #     "gpu": "2",
    #     "dataset": "ICEWS18",
    #     "history-len": "6",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "conf-threshold":"0.8",
    #     "use-conf":"1",
    #     "use-query":"1",
    # },

    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "0",
        "dataset": "ICEWS18",
        "history-len": "4",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "conf-threshold":"0.0",
        "use-conf":"0",
        "use-query":"1",
    },
    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "0",
        "dataset": "ICEWS18",
        "history-len": "5",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "conf-threshold":"0.0",
        "use-conf":"0",
        "use-query":"1",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python","../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_QGTC_Net.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")
# Out:
# Process finished with return code 0
# Process finished with return code 0

# %% [markdown]
# # ConvE性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"ConvE",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"ConvE",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "1",
        "dataset": "WIKI",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"ConvE",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python","../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_ConvE.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # DisMult的性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"DisMult",
        "noise-strategy":"1",
        "filter":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"DisMult",
        "noise-strategy":"1",
        "filter":"1",
        "gpu": "1",
        "dataset": "WIKI",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"DisMult",
        "noise-strategy":"1",
        "filter":"1",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python","../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_DisMult.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # CyGNet的性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.1",
        "model":"CyGNet",
        "noise-strategy":"1",
        "filter":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },
    {
        "mode": "train",
        "neg-ratio":"0.1",
        "model":"CyGNet",
        "noise-strategy":"1",
        "filter":"1",
        "gpu": "1",
        "dataset": "WIKI",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },
    {
        "mode": "train",
        "neg-ratio":"0.1",
        "model":"CyGNet",
        "noise-strategy":"1",
        "filter":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python","../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_CyGNet.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # TransE的性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "model":"TransE",
    #     "noise-strategy":"1",
    #     "filter":"1",
    #     "attack":"raw",
    #     "gpu": "0",
    #     "dataset": "YAGO",
    #     "history-len": "1",
    #     "lambda1": "0.0",
    #     "lambda2": "0.0",
    #     "lambda3": "0.0",
    # },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"TransE",
        "noise-strategy":"1",
        "filter":"1",
        "attack":"raw",
        "gpu": "1",
        "dataset": "WIKI",
        "history-len": "1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
    },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "model":"TransE",
    #     "noise-strategy":"1",
    #     "filter":"1",
    #     "attack":"raw",
    #     "gpu": "1",
    #     "dataset": "ICEWS14",
    #     "history-len": "1",
    #     "lambda1": "0.0",
    #     "lambda2": "0.0",
    #     "lambda3": "0.0",
    # },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python","../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_TransE.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 在ICEWScut10上寻找好的性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.1",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.1",
        "lambda3": "1.5",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.01",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.5",
        "lambda3": "0.5",
        "encoder": "RGCN"
    },

    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.1",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.1",
        "lambda3": "1.5",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.01",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.5",
        "lambda3": "0.5",
        "encoder": "RGCN"
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 实体初始化 normal_ 和 xavier_normal 对效果有很大的影响，前者能够有很好的鲁棒性

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
     {
        "mode": "train",
        "neg-ratio":"0.0",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "3",
        "init-method":"xavier+normal",
        "init-std":"1.0",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
     {
        "mode": "train",
        "neg-ratio":"0.0",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "WIKI",
        "history-len": "3",
        "init-method":"xavier+normal",
        "init-std":"1.0",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
     {
        "mode": "train",
        "neg-ratio":"0.0",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "history-len": "3",
        "init-method":"xavier+normal",
        "init-std":"1.0",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
     {
        "mode": "train",
        "neg-ratio":"0.0",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14s",
        "history-len": "3",
        "init-method":"xavier+normal",
        "init-std":"1.0",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_init_method_exp.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 分析不同方差对于normal_作用于 REGCN模型的影响

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "3",
        "init-method":"normal",
        "init-std":"0.01",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "3",
        "init-method":"normal",
        "init-std":"0.05",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "3",
        "init-method":"normal",
        "init-std":"0.08",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "YAGO",
        "history-len": "3",
        "init-method":"normal",
        "init-std":"0.1",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "YAGO",
        "history-len": "3",
        "init-method":"normal",
        "init-std":"0.15",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "model":"REGCN",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "YAGO",
        "history-len": "3",
        "init-method":"normal",
        "init-std":"0.18",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "encoder": "RGCN"
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_init_std_exp.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # HGLS的性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "dataset": "YAGO-N1",
        "gpu":"0",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },
    {
        "dataset": "WIKI-N1",
        # "relation-prediction":"",
        "gpu":"1",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },
    {
        "dataset": "ICEWS14-N1",
        # "relation-prediction":"",
        "gpu":"1",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../01HGLS/main.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        if len(str(value))>0:
            command.append(str(value)) 
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_HGLS.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    # print(commands)
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # CENET 性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "dataset": "YAGO",
        "gpu":"0",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },
    {
        "dataset": "YAGO-N3",
        "gpu":"0",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },

    {
        "dataset": "WIKI",
        "gpu":"1",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },
    {
        "dataset": "WIKI-N3",
        "gpu":"1",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },


    {
        "dataset": "ICEWS14",
        "gpu":"0",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },
    {
        "dataset": "ICEWS14-N3",
        "gpu":"0",
        "long":"",
        "short":"",
        "lr":"0.001",
        "fuse":"gate",
        "r_fuse":"gate",
        "model_record":"",
    },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../06CENET/main.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        if len(str(value))>0:
            command.append(str(value)) 
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_HGLS.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    # print(commands)
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # LogCL性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "dataset": "ICEWS18-N1",
        "train-history-le":"3",
        "test-history-len":"3",
        "dilate-len":"",
        "lr":"0.001",
        "gpu":"0",
        "filter":"1",
        "pre-weight":"0.9",
        "temperature":"0.03",
        "dilate-len":"1"
    },
    {
        "dataset": "ICEWS18-N2",
        "train-history-le":"3",
        "test-history-len":"3",
        "dilate-len":"",
        "lr":"0.001",
        "gpu":"1",
        "filter":"1",
        "pre-weight":"0.9",
        "temperature":"0.03",
        "dilate-len":"1"
    },
    {
        "dataset": "ICEWS18-N1",
        "train-history-le":"3",
        "test-history-len":"3",
        "dilate-len":"",
        "lr":"0.001",
        "filter":"1",
        "gpu":"2",
        "pre-weight":"0.9",
        "temperature":"0.03",
        "dilate-len":"1"
    },
    {
        "dataset": "ICEWS18",
        "train-history-le":"3",
        "test-history-len":"3",
        "dilate-len":"",
        "lr":"0.001",
        "filter":"1",
        "gpu":"3",
        "pre-weight":"0.9",
        "temperature":"0.03",
        "dilate-len":"1"
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../07LogCL/src/main.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        if len(str(value))>0:
            command.append(str(value)) 
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_LogCL.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    # print(commands)
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # RENET 性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "dataset": "YAGO",
        "gpu":"0",
    },
    {
        "dataset": "WIKI",
        "gpu":"1",
    },
    {
        "dataset": "ICEWS14",
        "gpu":"0",
    },
    {
        "dataset": "YAGO-N3",
        "gpu":"0",
    },
    {
        "dataset": "WIKI-N3",
        "gpu":"1",
    },
    {
        "dataset": "ICEWS14-N3",
        "gpu":"0",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../05RENet/train.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        if len(str(value))>0:
            command.append(str(value)) 
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_RENet.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    # print(commands)
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # xERTE 性能

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "dataset": "YAGO",
        "device":"0",
        "load-checkpoint":"",
    },
    {
        "dataset": "WIKI",
        "device":"1",
    },
    {
        "dataset": "ICEWS14",
        "device":"0",
    },
    {
        "dataset": "YAGO-N3",
        "device":"0",
    },
    {
        "dataset": "WIKI-N3",
        "device":"1",
    },
    {
        "dataset": "ICEWS14-N3",
        "device":"0",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../03xERTE/eval.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        if len(str(value))>0:
            command.append(str(value)) 
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_xERTE.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    # print(commands)
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 重新测试 上下文 置信度

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "WIKI",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN"
    },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # Proposed model

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "YAGO",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.8",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "1",
    #     "dataset": "WIKI",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.8",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "ICEWS14",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.5",
    # },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS18",
        "history-len": "6",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.6",
    },
    {
        "mode": "train",
        "neg-ratio":"0.1",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS18",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.6",
        "mode":"train"
    },
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS18",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.6",
        "mode":"train"
    },

]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 参数敏感性实验：conf-threshold

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        # "attack":"raw",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.6",
        # "attack":"raw",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.7",
        # "attack":"raw",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.8",
        # "attack":"raw",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "YAGO",
        "history-len": "1",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.9",
        # "attack":"raw",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_conf_sensitivity.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 分析 query-guided embedding生效的原因

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "YAGO",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.8",
    #     "mode":"test",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "1",
    #     "dataset": "WIKI",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.8",
    #     "mode":"test",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "ICEWS14",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.5",
    #     "mode":"test",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "ICEWS18",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.6",
    #     "mode":"test",
    # },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"train",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut20",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"train",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut30",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"train",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut50",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"train",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "YAGO",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.8",
    #     "mode":"test",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "1",
    #     "dataset": "WIKI",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.8",
    #     "mode":"test",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "ICEWS14",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.5",
    #     "mode":"test",
    # },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.3",
    #     "noise-strategy":"1",
    #     "gpu": "0",
    #     "dataset": "ICEWS18",
    #     "history-len": "3",
    #     "lambda1": "1.0",
    #     "lambda2": "0.0",
    #     "lambda3": "1.0",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.6",
    #     "mode":"test",
    # },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"test",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut20",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"test",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut30",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"test",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "0",
        "dataset": "ICEWS14cut50",
        "history-len": "3",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        "mode":"test",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR_observe.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 消融试验

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.2",
        "gpu": "0",
        "dataset": "YAGO",
        "history-len": "1",
        "encoder": "RGCN",
        "conf-threshold":"0.7",
        # "use-query":"0",
        # "use-conf":"1",
        # "attack":"raw",
    },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.2",
    #     "gpu": "0",
    #     "dataset": "YAGO",
    #     "history-len": "1",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.7",
    #     # "use-query":"1",
    #     # "use-conf":"0",
    #     # "attack":"raw",
    # },

    {
        "mode": "train",
        "neg-ratio":"0.2",
        "gpu": "1",
        "dataset": "WIKI",
        "history-len": "2",
        "encoder": "RGCN",
        "conf-threshold":"0.7",
        # "use-query":"0",
        # "use-conf":"1",
        # "attack":"raw",
    },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.2",
    #     "gpu": "1",
    #     "dataset": "WIKI",
    #     "history-len": "2",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.7",
    #     # "use-query":"1",
    #     # "use-conf":"0",
    #     # "attack":"raw",
    # },

    {
        "mode": "train",
        "neg-ratio":"0.2",
        "gpu": "0",
        "attack":"raw",
        "dataset": "ICEWS14",
        "history-len": "3",
        "encoder": "RGCN",
        "conf-threshold":"0.5",
        # "use-query":"0",
        # "use-conf":"1",
        # "attack":"raw",
    },
    # {
    #     "mode": "train",
    #     "neg-ratio":"0.2",
    #     "attack":"raw",
    #     "gpu": "1",
    #     "dataset": "ICEWS14",
    #     "history-len": "3",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.5",
    #     # "use-query":"1",
    #     # "use-conf":"0",
    #     # "attack":"raw",
    # },

    {
        "mode": "train",
        "neg-ratio":"0.2",
        "gpu": "0",
        "dataset": "ICEWS18",
        "history-len": "3",
        "encoder": "RGCN",
        "conf-threshold":"0.8",
        # "use-query":"0",
        # "use-conf":"1",
    },
    # {
    #     "mode": "train",
    #     "attack":"raw",
    #     "gpu": "1",
    #     "dataset": "ICEWS18",
    #     "history-len": "3",
    #     "encoder": "RGCN",
    #     "conf-threshold":"0.8",
    #     "use-query":"1",
    #     "use-conf":"0",
    # },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_ablation.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")

# %% [markdown]
# # 参数敏感性： 窗口长度

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed
import os
# os.chdir(os.path.abspath("")+"/03_RobustTKG/MyWork/src_DGAD/ipynbFiles/")
# print(os.path.abspath(""))
# print(os.getcwd())

# 定义参数组合
param_combinations = [
   {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "1",
       "conf-threshold":"0.5",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "2",
        "conf-threshold":"0.5",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "3",
        "conf-threshold":"0.5",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "4",
        "conf-threshold":"0.5",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "5",
        "conf-threshold":"0.5",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "6",
        "conf-threshold":"0.5",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "7",
        "conf-threshold":"0.5",
    },
    {
        "mode": "train",
        "neg-ratio":"0.3",
        "noise-strategy":"1",
        "gpu": "1",
        "dataset": "ICEWS14",
        "lambda1": "1.0",
        "lambda3": "1.0",
        "history-len": "8",
        "conf-threshold":"0.5",
    },
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python", "../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_sensi_hislen_ICEWS14.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# # 使用 ProcessPoolExecutor 并行执行命令
# with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
#     commands = [create_command(params) for params in param_combinations]
#     futures = [executor.submit(run_command, cmd) for cmd in commands]
#     for future in as_completed(futures):
#         returncode = future.result()
#         print(f"Process finished with return code {returncode}")



# 依次执行每个参数组合
for params in param_combinations:
    command = create_command(params)
    print(f"Running command: {' '.join(command)}")
    returncode = run_command(command)
    if returncode == 0:
        print(f"Finished command successfully: {' '.join(command)}")
    else:
        print(f"Command failed with return code {returncode}: {' '.join(command)}")
# Out:
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 1 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 1 --conf-threshold 0.5
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 2 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 2 --conf-threshold 0.5
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 3 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 3 --conf-threshold 0.5
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 4 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 4 --conf-threshold 0.5
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 5 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 5 --conf-threshold 0.5
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 6 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 6 --conf-threshold 0.5
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 7 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 7 --conf-threshold 0.5
# Running command: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 8 --conf-threshold 0.5
# Finished command successfully: python ../MyWork/src_DGAD/main_TKGR.py --mode train --neg-ratio 0.3 --noise-strategy 1 --gpu 1 --dataset ICEWS14 --lambda1 1.0 --lambda3 1.0 --history-len 8 --conf-threshold 0.5

# %% [markdown]
# # 为什么ICEWS14上性能猛增

# %%
import subprocess
from concurrent.futures import ProcessPoolExecutor, as_completed

# 定义参数组合
param_combinations = [
    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "2",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "conf-threshold":"0.5",
        "use-conf":"0",
        "use-query":"1",
    },
    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "0",
        "dataset": "ICEWS14cut10",
        "history-len": "2",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "conf-threshold":"0.5",
        "use-conf":"1",
        "use-query":"0",
    },

    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "2",
        "dataset": "ICEWS14cut20",
        "history-len": "2",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "conf-threshold":"0.5",
        "use-conf":"0",
        "use-query":"1",
    },
    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "2",
        "dataset": "ICEWS14cut20",
        "history-len": "2",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "conf-threshold":"0.5",
        "use-conf":"1",
        "use-query":"0",
    },

    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "3",
        "dataset": "ICEWS14cut30",
        "history-len": "2",
        "lambda1": "0.0",
        "lambda2": "0.0",
        "lambda3": "0.0",
        "conf-threshold":"0.5",
        "use-conf":"0",
        "use-query":"1",
    },
    {
        "mode": "train",
        "neg-ratio":"0.4",
        "model":"REGCN",
        "noise-strategy":"1",
        "filter":"1",
        # "attack":"raw",
        "gpu": "3",
        "dataset": "ICEWS14cut30",
        "history-len": "2",
        "lambda1": "1.0",
        "lambda2": "0.0",
        "lambda3": "1.0",
        "conf-threshold":"0.5",
        "use-conf":"1",
        "use-query":"0",
    },

    
]

# 将参数组合转换为命令行参数列表
def create_command(params):
    command = ["python","../MyWork/src_DGAD/main_TKGR.py"]
    for key, value in params.items():
        command.append(f"--{key}")
        command.append(str(value))
    return command

# 执行单个命令的函数
def run_command(command):
    with open('nohup_QGTC_Net_ICEWS14_why_great.out', 'a') as f:
        result = subprocess.run(command, stdout=f, stderr=subprocess.STDOUT, text=True)
    return result.returncode

# 使用 ProcessPoolExecutor 并行执行命令
with ProcessPoolExecutor(max_workers=len(param_combinations)) as executor:
    commands = [create_command(params) for params in param_combinations]
    futures = [executor.submit(run_command, cmd) for cmd in commands]
    for future in as_completed(futures):
        returncode = future.result()
        print(f"Process finished with return code {returncode}")
